# %% [markdown]
# IMPORT LIBRARIES

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# LOAD CSV FILE

# %%
#read_csv() is used to read data from comma seperated values file
#file name - updated-patients-united-states.csv
# 'r' is used brfore the path to convert the string to a raw sting
df = pd.read_csv(r'~\Desktop\DA DS\updated-patients-united-states.csv')

# %% [markdown]
# EXPLORATORY DATA ANALYSIS AND DATA CLEANING

# %%
#view first 05 entries
df.head()
# Out:
#    Row ID    Procedure ID Procedure Date (Order Date)       Discharge Date  \
# 0       1  CA-2017-152156         2017-11-08 00:00:00  2017-11-11 00:00:00
# 1       2  CA-2017-152156         2017-11-08 00:00:00  2017-11-11 00:00:00
# 2       3  CA-2017-138688         2017-06-12 00:00:00  2017-06-16 00:00:00
# 3       4  US-2016-108966         2016-10-11 00:00:00  2016-10-18 00:00:00
# 4       5  US-2016-108966         2016-10-11 00:00:00  2016-10-18 00:00:00
#
#   Ship Mode Patient ID      Segment        Country             City  \
# 0    Deluxe   CG-12520  Non-Insured  United States        Henderson
# 1    Deluxe   CG-12520  Non-Insured  United States        Henderson
# 2    Deluxe   DV-13045      Insured  United States      Los Angeles
# 3  Standard   SO-20335  Non-Insured  United States  Fort Lauderdale
# 4  Standard   SO-20335  Non-Insured  United States  Fort Lauderdale
#
#         State  ...  Region     Category                    Sub-Category  \
# ...

# %%
#view last 10 entries
df.tail(10)
# Out:
#       Row ID    Procedure ID Procedure Date (Order Date)       Discharge Date  \
# 9984    8491  CA-2017-158841         2017-02-02 00:00:00  2017-02-04 00:00:00
# 9985    8492  CA-2018-106824         2018-07-07 00:00:00  2018-07-11 00:00:00
# 9986    8493  CA-2016-109190         2016-10-23 00:00:00  2016-10-28 00:00:00
# 9987    8494  CA-2016-109190         2016-10-23 00:00:00  2016-10-28 00:00:00
# 9988    8495  CA-2016-109190         2016-10-23 00:00:00  2016-10-28 00:00:00
# 9989    8496  CA-2017-143154         2017-12-02 00:00:00  2017-12-08 00:00:00
# 9990    8497  CA-2015-169061         2015-03-05 00:00:00  2015-03-08 00:00:00
# 9991    8498  CA-2015-169061         2015-03-05 00:00:00  2015-03-08 00:00:00
# 9992    8499  CA-2015-169061         2015-03-05 00:00:00  2015-03-08 00:00:00
# 9993    8500  CA-2015-169061         2015-03-05 00:00:00  2015-03-08 00:00:00
#
#      Ship Mode Patient ID      Segment        Country         City  \
# ...

# %%
#find the dimensions of the data being worked upon
df.shape
# Out:
# (9994, 21)

# %%
# find out the columns in data set
df.columns
# Out:
# Index(['Row ID', 'Procedure ID', 'Procedure Date (Order Date)',
#        'Discharge Date', 'Ship Mode', 'Patient ID', 'Segment', 'Country',
#        'City', 'State', 'Postal Code', 'Region', 'Category', 'Sub-Category',
#        'Sales', 'Days (Quantity)', 'Discount', 'Profit', 'Discount_Amount',
#        'Relapses', 'Person'],
#       dtype='object')

# %%
# find the meta data of the data set 
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 21 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Row ID                       9994 non-null   int64
#  1   Procedure ID                 9994 non-null   object
#  2   Procedure Date (Order Date)  9994 non-null   object
#  3   Discharge Date               9994 non-null   object
#  4   Ship Mode                    9994 non-null   object
#  5   Patient ID                   9994 non-null   object
#  6   Segment                      9994 non-null   object
#  7   Country                      9994 non-null   object
#  8   City                         9994 non-null   object
#  9   State                        9994 non-null   object
#  10  Postal Code                  9983 non-null   float64
#  11  Region                       9994 non-null   object
#  12  Category                     9994 non-null   object
# ...

# %%
df['Procedure Date (Order Date)'] = pd.to_datetime(df['Procedure Date (Order Date)'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 21 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Row ID                       9994 non-null   int64
#  1   Procedure ID                 9994 non-null   object
#  2   Procedure Date (Order Date)  9994 non-null   datetime64[ns]
#  3   Discharge Date               9994 non-null   object
#  4   Ship Mode                    9994 non-null   object
#  5   Patient ID                   9994 non-null   object
#  6   Segment                      9994 non-null   object
#  7   Country                      9994 non-null   object
#  8   City                         9994 non-null   object
#  9   State                        9994 non-null   object
#  10  Postal Code                  9983 non-null   float64
#  11  Region                       9994 non-null   object
# ...

# %%
# some of the columns have object as data type - MEANS THEY ARE CATEGORICAL COLUMNS
# We can see how many unique values are there in each object data type columns
# this is done using describe()
# describe() is only for numbers, BUT WHEN 'incluce='object'', it gives summary statistics for for object columns
df.describe( include='object' )
# Out:
#           Procedure ID       Discharge Date Ship Mode Patient ID      Segment  \
# count             9994                 9994      9994       9994         9994
# unique            5009                 1334         4        793            3
# top     CA-2018-100111  2016-12-16 00:00:00  Standard   WB-21850  Non-Insured
# freq                14                   35      5968         37         5191
#
#               Country           City       State Region     Category  \
# count            9994           9994        9994   9994         9994
# unique              1            531          49      4            3
# top     United States  New York City  California   West  Orthopedics
# freq             9994            915        2001   3203         6026
#
#        Sub-Category Relapses         Person
# count          9994      800           9994
# unique           16        2              4
# top     ACL Surgery       No  Anna Andreadi
# freq           1989      651           3203

# %%
#determine what unique values are there in each object using a for loop
for col in df.describe( include='object' ).columns:
    print(col)
    print(df[col].unique())
    print(100*'-')
# Out:
# Procedure ID
# ['CA-2017-152156' 'CA-2017-138688' 'US-2016-108966' ... 'CA-2018-106824'
#  'CA-2016-109190' 'CA-2017-143154']
# ----------------------------------------------------------------------------------------------------
# Discharge Date
# ['2017-11-11 00:00:00' '2017-06-16 00:00:00' '2016-10-18 00:00:00' ...
#  '2018-04-16 00:00:00' '2015-06-30 00:00:00' '2018-02-15 00:00:00']
# ----------------------------------------------------------------------------------------------------
# Ship Mode
# ['Deluxe' 'Standard' 'Twin Sharing' 'Suite']
# ----------------------------------------------------------------------------------------------------
# Patient ID
# ['CG-12520' 'DV-13045' 'SO-20335' 'BH-11710' 'AA-10480' 'IM-15070'
#  'HP-14815' 'PK-19075' 'AG-10270' 'ZD-21925' 'KB-16585' 'SF-20065'
#  'EB-13870' 'EH-13945' 'TB-21520' 'MA-17560' 'GH-14485' 'SN-20710'
#  'LC-16930' 'RA-19885' 'ES-14080' 'ON-18715' 'PO-18865' 'LH-16900'
# ...

# %%
df.isnull().sum()
# Out:
# Row ID                            0
# Procedure ID                      0
# Procedure Date (Order Date)       0
# Discharge Date                    0
# Ship Mode                         0
# Patient ID                        0
# Segment                           0
# Country                           0
# City                              0
# State                             0
# Postal Code                      11
# Region                            0
# Category                          0
# Sub-Category                      0
# Sales                             0
# Days (Quantity)                   0
# Discount                          0
# Profit                            0
# Discount_Amount                   0
# Relapses                       9194
# Person                            0
# dtype: int64

# %%
df.shape
# Out:
# (9994, 21)

# %%
#drop Relapses as 9194 missing values are there out of 9994 records
# drop Postal code as 11 values are missing
df.drop(['Relapses','Postal Code'], axis = 1, inplace = True)
# dropna() method removes the rows that contains NULL values
df.dropna(inplace = True)

# %%
#check, if any null values are still present in the data
df.isnull().sum()
# Out:
# Row ID                         0
# Procedure ID                   0
# Procedure Date (Order Date)    0
# Discharge Date                 0
# Ship Mode                      0
# Patient ID                     0
# Segment                        0
# Country                        0
# City                           0
# State                          0
# Region                         0
# Category                       0
# Sub-Category                   0
# Sales                          0
# Days (Quantity)                0
# Discount                       0
# Profit                         0
# Discount_Amount                0
# Person                         0
# dtype: int64

# %% [markdown]
# THE ABLOVE OUTPUT SHOWS THAT ALL NULL OR MISSING VALUE COLUMNS ARE REMOVED FROM DATA

# %%
#determine, if there are any outliers
# describe() give the summany statistics of numerical columns
df.describe()
# Out:
#             Row ID    Procedure Date (Order Date)         Sales  \
# count  9994.000000                           9994   9994.000000
# mean   4997.500000  2017-04-30 05:17:08.056834048    229.858001
# min       1.000000            2015-01-03 00:00:00      0.444000
# 25%    2499.250000            2016-05-23 00:00:00     17.280000
# 50%    4997.500000            2017-06-26 00:00:00     54.490000
# 75%    7495.750000            2018-05-14 00:00:00    209.940000
# max    9994.000000            2018-12-30 00:00:00  22638.480000
# std    2885.163629                            NaN    623.245101
#
#        Days (Quantity)     Discount       Profit  Discount_Amount
# count      9994.000000  9994.000000  9994.000000      9994.000000
# mean          3.789574     0.156203    28.656896        32.277580
# min           1.000000     0.000000 -6599.978000         0.000000
# 25%           2.000000     0.000000     1.728750         0.000000
# ...

# %%
#determine how far is the outlier using box plot
df['Discount_Amount'].plot( kind = 'box')
# Out:
# <Axes: >

# %%
#determine how far is the outlier using box plot
df['Sales'].plot( kind = 'box')
# Out:
# <Axes: >

# %%
# remove the outliers by metioning the upper bound
df = df[df['Sales']<15000]

# %%
##remove the outliers by metioning the upper bound
df = df[df['Discount_Amount']<5000]

# %%
# check the distribution again to see for outliers
df['Sales'].plot( kind = 'box')
# Out:
# <Axes: >

# %%
# check the distribution again to see for outliers
df['Discount_Amount'].plot( kind = 'box')
# Out:
# <Axes: >

# %%
df.describe()
# Out:
#             Row ID    Procedure Date (Order Date)         Sales  \
# count  9992.000000                           9992   9992.000000
# mean   4997.547038  2017-04-30 06:46:24.307445760    225.886953
# min       1.000000            2015-01-03 00:00:00      0.444000
# 25%    2498.750000            2016-05-23 00:00:00     17.272000
# 50%    4997.500000            2017-06-26 00:00:00     54.432000
# 75%    7496.250000            2018-05-14 00:00:00    209.932500
# max    9994.000000            2018-12-30 00:00:00  13999.960000
# std    2885.302626                            NaN    555.323418
#
#        Days (Quantity)     Discount       Profit  Discount_Amount
# count      9992.000000  9992.000000  9992.000000      9992.000000
# mean          3.789231     0.156184    28.003215        31.151210
# min           1.000000     0.000000 -6599.978000         0.000000
# 25%           2.000000     0.000000     1.730250         0.000000
# ...

# %%
# remove the outliers by metioning the upper bound
df = df[df['Sales']<12000]
##remove the outliers by metioning the upper bound
df = df[df['Discount_Amount']<2500]

# %%
df.describe()
# Out:
#             Row ID    Procedure Date (Order Date)         Sales  \
# count  9987.000000                           9987   9987.000000
# mean   4997.725743  2017-04-30 05:32:47.077200384    221.688453
# min       1.000000            2015-01-03 00:00:00      0.444000
# 25%    2499.500000            2016-05-23 00:00:00     17.248000
# 50%    4997.000000            2017-06-26 00:00:00     54.368000
# 75%    7495.500000            2018-05-14 00:00:00    209.746000
# max    9994.000000            2018-12-30 00:00:00  11199.968000
# std    2884.954966                            NaN    518.310320
#
#        Days (Quantity)     Discount       Profit  Discount_Amount
# count      9987.000000  9987.000000  9987.000000      9987.000000
# mean          3.788625     0.156062    28.413749        29.787618
# min           1.000000     0.000000 -3701.892800         0.000000
# 25%           2.000000     0.000000     1.733400         0.000000
# ...

# %%
df['Profit'].plot( kind = 'box')
# Out:
# <Axes: >

# %% [markdown]
# THIS CONCLUDES CLEANING OF THE DATA

# %% [markdown]
# DATA ANALYSIS AND VISUALISATION BEGINS

# %%
deluxe_perc = (df['Ship Mode']=='Deluxe').value_counts(normalize = True)
print(deluxe_perc)
# Out:
# Ship Mode
# False    0.805247
# True     0.194753
# Name: proportion, dtype: float64

# %%
# Standard, Twin Sharing Suite
std_perc = (df['Ship Mode']=='Standard').value_counts(normalize = True)
print(std_perc)
# Out:
# Ship Mode
# True     0.597076
# False    0.402924
# Name: proportion, dtype: float64

# %%
suite_perc = (df['Ship Mode']=='Suite').value_counts(normalize = True)
print(suite_perc)
# Out:
# Ship Mode
# False    0.945729
# True     0.054271
# Name: proportion, dtype: float64

# %%
#Twin Sharing
ts_perc = (df['Ship Mode']=='Twin Sharing').value_counts(normalize = True)
print(ts_perc)
# Out:
# Ship Mode
# False    0.8461
# True     0.1539
# Name: proportion, dtype: float64

# %%
 0.1539+0.054271+ 0.597076+0.194753
# Out:
# 1.0

# %%
room_type = df['Ship Mode']
#print(room_type)
room_type_distri = room_type.value_counts()
plt.figure(figsize=(5,5))
plt.title("Occupany of different room")
plt.pie(room_type_distri, autopct = '%.2f', labels = room_type_distri.index )
fontsize = 30
plt.show()
